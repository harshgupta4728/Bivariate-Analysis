# %%
import matplotlib.pyplot as plt

# Replace these lists with your actual data
test_names = ["Cycle Test 1", "Cycle Test 2", "Cycle Test 3", "Cycle Test 4", "Cycle Test 5"]
test_scores = [85, 78, 92, 88, 95]

# Create a bar plot
plt.bar(test_names, test_scores, color='blue')

# Add labels and title
plt.xlabel('Cycle Tests')
plt.ylabel('Marks')
plt.title('Cycle Test Scores')

# Show the plot
plt.show()
